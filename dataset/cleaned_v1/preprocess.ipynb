# %%
from transformers import (
    AutoTokenizer, AutoModelForMaskedLM, 
)

# import nlpaug.augmenter.char as nac
# import nlpaug.augmenter.word as naw
# import nlpaug.augmenter.sentence as nas
# import nlpaug.flow as nafc
# from nlpaug.util import Action

# from googletrans import Translator
# import translators as ts

import re, math, random, json
from sklearn.model_selection import StratifiedKFold
import pandas as pd
from tqdm import tqdm
# import demoji

from cleantext import clean
# from pykospacing import Spacing
# from hanspell import spell_checker

# %%
# train_json = './dataset//nikluge-sa-2022-train.jsonl'
# train_raw = pd.read_json(train_json, lines=True)
# train_raw.annotation = train_raw.annotation.apply(lambda x: str(x))
# train_raw = train_raw[['sentence_form', 'annotation']]
# dup = train_raw.duplicated(keep=False)
# train_raw[dup]

# %%
# dev_json = './dataset/nikluge-sa-2022-dev.jsonl'
# dev_raw = pd.read_json(dev_json, lines=True)
# dev_raw.annotation = dev_raw.annotation.apply(lambda x: str(x))
# dev_raw = dev_raw[['sentence_form', 'annotation']]
# dup = dev_raw.duplicated(keep=False)
# dev_raw[dup]

# %%
train_json = './dataset/nikluge-sa-2022-train.jsonl'
dev_json = './dataset/nikluge-sa-2022-dev.jsonl'
test_json = './dataset/nikluge-sa-2022-test.jsonl'

# %%
train = pd.read_json(train_json, lines=True)
dev = pd.read_json(dev_json, lines=True)
test = pd.read_json(test_json, lines=True)

# %%
# train.iloc[2319]
train = train.drop(2319)
# dev.iloc[1692]
dev = dev.drop(1692)

# %% [markdown]
# # Preprocess

# %% [markdown]
# ## Cleansing

# %% [markdown]
# ### Before

# %%
for el in train.sample(n=15, frac=None, replace=False, weights=None, random_state=None, axis=None, ignore_index=False).sentence_form:
    print(el)
# Out:
# 그냥 모기장만 설치했을때도 예뻤지만 보태니컬 가랜드랑 같이 해놓으니 더 만족도 UP
# 내가 좋아하는 아기옷브랜드 #에뜨와
# 저처럼 #건성피부 라면 더욱 만족을 느끼실 것 같은 #수분력 도 짱짱!
# 놀라운 자연스러운 #보습 과 #광
# 이뽀+_+
# 밤에 감으면 좋은 샴푸래요
# 대박! ㅋㅋ
# 믿고 쓰는 #뷰티챌린지 베스트템
# 미니냉장고가방으로 불리는 이유가 있어
# 운동 끝나고 승모근 쪽 당길때도 마사지하기에도 좋고!👏🏻👏🏻
# 60초면 흡수 끝!!
# 100% 무기자외선차단 성분으로 더욱 순하게 향도 순하니 좋다!
# 그렇다고 가격이 그렇게 비싸냐하면 절대 그렇지 않다.
# 물을 흡수하는 구조가 아니라서 오염에도 걱정 NO
# 부드럽고 촉촉하게 클렌징 하나로 홈케어 마사지로 깨끗하게 클렌징

# %%
def preprocess(text):
    text = re.sub(r'&.+&', '<숨김>', text)
    text = re.sub(r'[^A-Za-z0-9가-힣]', ' ', text)
    
    text = clean(
        text,
        fix_unicode=False,
        to_ascii=False,
        lower=True,
        normalize_whitespace=True,
        no_line_breaks=False,
        strip_lines=True,
        keep_two_line_breaks=False,
        no_urls=False,
        no_emails=False,
        no_phone_numbers=False,
        no_numbers=True,
        no_digits=True,
        no_currency_symbols=False,
        no_punct=True,
        no_emoji=True,
        replace_with_url="<URL>",
        replace_with_email="<EMAIL>",
        replace_with_phone_number="<PHONE>",
        replace_with_number="0",
        replace_with_digit="0",
        replace_with_currency_symbol="<CUR>",
        replace_with_punct="",
        lang="en",
    )
    
    # sent = demoji.replace_with_desc(string=sent, sep= " ")
    # sent = re.sub(r'\s+', ' ', sent)
    # sent = re.sub(r'^#$', '', sent)
    
    # text = re.sub(r'[A-Za-z]+', 'alphabet', text)
    # text = re.sub(r'[`~$^+=|><]', '', text)
    # text = re.sub(r'[ㄱ-ㅎ|ㅏ-ㅣ]', '', text)
    
    # text = spacing(text)
    # text = spell_checker.check(text).checked
    return text.upper().strip()

# %%
train.sentence_form = train.sentence_form.apply(preprocess)
dev.sentence_form = dev.sentence_form.apply(preprocess)
test.sentence_form = test.sentence_form.apply(preprocess)
total = pd.concat([train, dev, test])

# %% [markdown]
# Test

# %%
case = total.sentence_form.str.contains('r[^A-Za-z0-9가-힣\s]+', case=False, flags=0, na=None, regex=True)
for e in total[case].sentence_form:
    print(e)

# %% [markdown]
# ### After

# %%
for el in total.sample(n=25, frac=None, replace=False, weights=None, random_state=None, axis=None, ignore_index=False).sentence_form:
    print(el)
# Out:
# 인케어가 건조한 모발을 촉촉하게 채워주고 아웃케어가 모발표면을 코팅하여 매끄럽고 단단하게
# 브랜드 만족도
# 나는 피부가 예민한 편이라 순한 제품이 잘 맞는데 유칼립투스버블샴푸앤바스 를 폼클렌징으로 사용하면서부터 뾰루지도 잘 안나고 만족해서 계속 쓰는중
# 앞으로 쭉쭉 듀이셀 사용해서 피부만은 나이먹지 않게 관리해야지
# 베베누보 신상품 침낭형 낮잠이불로 요즘 재워보고 있는데 패드가 우선 도톰하고 일체형또는 분리할수있어 편합니다
# 0회용 제품이라 나에게 얼마나 사용하는지 확인할 수 있어 믿음이 확 가는 제품이에요
# 성능과 더불어 전력 효율까지 향상되었고 램도 DDR0 0GB 0000MHZ 램으로 전력 효율과 성능이 향상된 제품입니다
# 피부밸런스를 맞춰주는 홀플랜트이펙트 성분이 원래의 건강한 피부로 리턴
# 구성이 아주 빵빵합니당
# 여기서 건져갈게 이거밖에
# 스타일00 00대여자선물추천하는 스와로브스키 잉크벨벳틴트 중 발렌타인 키스 레드를 바르고 대표사진 찰칵
# 크림쓰고 엄청 만족스러웠는데 치약도 맘에 쏙
# 다크닝없이 깨끗하게 피부를 커버를 해줘 내가 바르는 비비크림
# 붉은기 많고 푸석했던 피부가 자기전에 간단히 슬리핑팩 발라주고 나니 다음날 아침에 촉촉하고 피부도 맑아진게 보여서 넘 좋더라구요
# 원래 쓰던 노트북도 엘지라서 이번에도 엘지로 가고 싶었고 그렇게 총 네가지 모델로 좁혀졌다
# 0 IN 0 이라 완전 편하다
# 세번째 엄청난 가성비
# 피부가 숨 쉬는 여름에 최적인 여름용기저귀
# 이 인증은 동물성 원료 및 유래 원료를 포함하지 않으며 동물 실험을 하지 않았다는 의미로 더욱 안심하고 사용할 수 있느 화장품이에요
# 가성비좋은휴지 로 잘풀리는집휴지 추천해요
# 피지는 잡아주고 수분은 지켜주는 매직펜
# 기초바르고마지막에 큐어크림 바르고메이크업하면 완전 화장잘먹음
# 리얼코튼은 부드럽게 아기 엉덩이에 터치
# 피로감도 덜하고 몸이 한결 가벼워진 느낌
# 꾸준히 사용하고 있는 리파캐럿

# %%
total['check'] = total.sentence_form.str.find('OO')
for row in total[total.check > -1].sentence_form:
    print(row)
# Out:
# OO이유식 들어가면서 만들어줘야겠다 생각했는데 역시나 넘나 간편한 베이비쿡솔로
# OO때부터 애정하며 사용중이지
# OO칫솔 로 핫한 쿨샤전동칫솔 로 바꿨어요
# OO가 사용할거라서 가성비 좋은 놈으로 겟
# 환절기라 메이크업을 해도 늘 좀 칙칙한 느낌이 있었는데 요즘은 화사한 OO랄까
# 패딩을 입어도 빛이나는 건 OO씨가 예뻐서 그런건가 패딩이 예뻐서 그런건가
# OO씨가 이날 장착한 패딩과 신발은 모두 오니즈카타이거 제품이었는데요
# 거울보니까 내가봐도 예쁜데 OO도 자꾸 예쁘다해주니까 좋다
# 디올선미레드 라는 애칭이 벌써 붙었을만큼 핫한 000레드 컬러는 OO씨도 사용했네욤
# OO추천템
# 좋아하는 뷰티유튜버 OO가 만든 쿠션제품이라고 해서 어떨지 넘나 궁금했는데 직접 써보니 대박 촉촉하고 컬러감 대박
# OO의 애정템 이라하여 써본것이 벌써 몇 개째 쓰고있는지
# 이젠 고민말고 OO 너도 하나 겟하는 건 어때
# 푸석푸석 손상이심한 모발때문에 고민이많았는데 친구 추천으로 써본 헤드스파0 OO씨도 쓴다던데 역시 너무 좋네요
# 워낙 그립감이 좋아 OO가 써보더니 엄마는 손도 못대게 하더군요
# 출입이 자유로운 지퍼디자인 덕분에 OO가 답답해하지 않구 좋아하네요
# 친숙한 캐릭터라 OO가 좋아하구 다용도 끈이 있어 어디든 걸수있다는 장점
# 디자인도 OO한테 잘어울려서 올여름내내 입히겠어요
# OO랑 놀러갈라믄 챙겨야될것들이 느무 많아서 고민이었는데 더블보냉가방 하나믄 끝나겠어요
# OO와 함께하는 나들이 에는 보냉백 과 쇼퍼백 을 한번에 해결되는 마들린 더블 보온보냉백
# OO가 보자마자 좋아해서 엄마는 그것만 봐도 행복했어요
# 조금만 더워도 땀흘리는 OO에게 완전 딱 맞는 실내복이네요
# 자연주의 0배 고농축이라 적은양으로도 세탁효과 대박이고 유해물질을 사용하지않아 안전하니 OO전용으로 세탁할때 사용중이에요
# 트렌드위드미에서 OO가 사용해 인싸템이 되어버린 톤업썬크림
# OO향수로도 유명한 일본 향수 브랜드
# 디자인도 예쁘고 뚜껑은 OO가 갖고 놀기도 하는중
# 활동적인 OO에게 편하게 입힐수있어 좋으다
# OO 애정템이라 참 좋아해서 엄마도 덕분에 편하게 외식해요
# OO도 반한 텀블러
# 남아 00살 선택해서 받았더니 딱 우리 OO가 좋아하는 놀이감 가득
# 최근 OO 음악재생 하여 실컷 듣고 가끔은 좋아하는 라디오 도 듣고 누구 와 함께라면 지루할 틈 없어요
# 울 OO의 활동성을 높여주는 편안한 팬티기저귀
# 마이뷰티쁠에서 진행된 OO인플루언서픽 에서 맘에 쏙 들었던 제품
# 연예인 OO가 추천할 만큼 믿을 수 있는 쿠션이에용
# 아직 OO는 룰을 다 이해못해서 지들만의 방식으로 놀았는데 어찌나 좋아하던지 서로 역할을 바꿔가며 주말내내 게임을 즐겼다
# 샤워후 건조함도 없고 뽀송뽀송 보습력도 채워주니 GOOD
# 피부가 한번 뒤집히면 더 심해지고 급 올라오는 트러블에 바르기에 민감피부 진정에 GOOD
# 셀럽 OO씨도 애정한다는 달바
# 빠른흡수력 GOOD
# 산뜻하게 마무리 GOOD
# 탱글탱글 수분광이 예쁘고 슥발라도 촉촉하면서 발색GOOD
# 따뜻하니 우리 OO이 이제 궁디뜨끈 하겠네
# 울 OO가 소리에 반응하는 것 같아서 선택한 첨소리 소리나는 매트 겟
# 스마트폰 삼각대 추천 비소 셀카는 물론 가족사진 찍기도 GOOD
# 앞으로 OO이랑 저랑 둘이 야외 나가도 삼각대샷 예쁘게 남겨야지 호호호
# 커버력도 GOOD
# 거뭇거뭇 한 내 피부를 위해 사용중인 겟잇뷰티OO미백크림 으로 핫한 블랙샷프리미엄 미백크림
# 탑셀럽 여배우들의 고데기 사용 및 잦은 헤어컬러 체인지 등으로 극손상된 모발을 빠르게 회복시키기 위해 계발된 제품으로 OO 등 탑여배우들이 청담 이희 도산파크 살롱에서 실제 케어 받을 때 사용하는 이희트리트먼트
# 요거요거 우리 OO 맞춤 기저귀로 당첨
# 매일 OO의 몸에 직접 닿는 아기바디워시인지라 순하면서 자극없고 안전한 성분을 사용해야겠다 생각이 들어서 저자극으로 유해성분이 없는 아기바디워시를 찾다가 에바비바 바디워시를 선택했어요
# OO가 안락해 하니 이번 세이지폴 멀티바운서도 성공
# 얼릉 OO 나오면 사용해 보고 싶은 바운서D
# HAVE A GOOD NIGHT WITH 설안팩
# FASHION 팔로우미00 MC OO가 운동복 니트 관리를 르주르로 하던데 은은한 향기가 솔솔
# 쉬드엘 아티스트웨어 스킨핏 리퀴드 파운데이션 지속력 좋고 커버력 좋고 밀착력도 GOOD
# 우리OO를 위해서 0 순간흡수 옆샘 방지 보솜이 리얼코튼팬티 쓰고있지요
# 특수 그물망구조로 가벼운 편이라 이동도 GOOD
# INBELLOOFFICIAL 천연화장품추천 토너 에멀젼 영양크림 클렌저 화장품세트 화장품선물 화장품브랜드 가성비좋은화장품 피부관리 속건조해결 속건조 KBEAUTY
# 오늘도 OO네는 몽디에스로 뽀송뽀송
# 애정하는 OO선수 도 쓴데서 완전 열심히 쓰고있는 마사지크림
# OO마스크 광고보며나에게 딱이다 했는데 정말 하루 0분 관리로탄력과 미백관리 끝
# OO팩트 로도 유명하죠
# HA원데이키트 는 피부 동안으로 유명한 OO씨의 애정템으로도 유명한데요
# OO가 조아하는 밀크향이라 양치시간이 즐거워
# 헤링본 패턴은 첨 써보는데 닦임성이 더 좋고 잘 찢어지지 않아서 GOOD
# OO가 사용해서 더 이뻐보이는 컬러감
# 세계적인 디자이너 OO의 제품인데 00000원 실화임
# 0번 AFTERNOON 도 좋아요
# OO 착한생리대 로 선정된 커버부터 흡수체까지 유기농 0 순면생리대 이다
# 깐깐하기로 이름난 OO의 인생템으로 꼽힌 이유를 알 것 같다
# 손 씻을때마다 메론향이 난다며 OO가 더 좋아하더라고요
# OO가 좋아하는걸보니 선택 잘했네요
# 목욕시간이 길어지긴 했지만 OO가 너무 신나게 놀아서 만족해요
# 끼워맞추는 퍼즐놀이를 좋아하는 OO에게 자석놀이를 통해 두뇌발달에 도움을 많이 주는 교구라 최고인거 같아요
# 아이새옷침구새가구새집증후군 청소위생관리생활용품 관리등 일상의 숨이 닿는 모든것들에 슥슥슥 뿌려주면 탈취효과 GOOD
# OO처럼 유아동기에는 올록볼록 CATCH EMBO 커버로 샐 걱정없고 맞춤 CATCH 커버로 사용하면 되니까요
# OO 주방세제로 안전하고 마켓컬리 주방세제부분 0위 대란템답게 만족도는 최고입니당
# 무엇보다 OO가 바를수있는 유아립밤 따로 필요없고 같이 바르면 되니까 언제 발라도 안심되는 베이비립밤 입니다
# 0 국내생산 순면이라 그런지 예민한 OO피부에도 자극없는걸 보니 흡수력이나 통기성이 정말 좋네요
# OO가 답답하면 기저귀를 잡아뜯는 그런 버릇이 있는데 킵기저귀는 얇고 순면감촉이라 편안한지 반응이 좋아요
# 시술이 아니라 OO리프팅기 카사업 으로 매일 사용했더니 예전 얼굴 나오네요
# 그래서 콧물 줄줄 흐르는 OO도 엄청 만족스러워하는 것 같은데 그래서인지 꿀잠자는 것 같기도 함
# 디저트 케이크 미니어쳐 를 마음껏 만들 수 있는 DIY완구 라서 키덜트 장난감 으로도 GOOD GOOD
# 가격대도 부담없으니 출산선물 하기에도 GOOD
# 특히 특유의 파우더향은 어느정도 개월수가 있는 OO의 쉬야나 끙아 냄새를 잡아줄 수 있기에 더욱 만족스럽더라고요
# 대용량이라 전신에 사용하기에도 GOOD GOOD
# 상콤한 레몬향에 맵지 않아 OO도 무난하게 잘 쓰고 있어요
# 은은한 펄감이 피부에 광채를 선사해 부담스럽지 않은 입체감 표현하기에 GOOD
# 천연 스파삼총사 인 미네랄워터 온천수 해수 가 깊고 풍부한 보습OO영양감으로 건강한 입술로 만들어준답니다
# 안그래도 최근에 본 OO 영상에서도 추천치약 탑오브탑에 뽑혔더라구요
# 홈케어 로 GOOD
# 알함브라궁전의추억 출연중인 배우OO 애정템 으로 유명하죠
# 빠른흡수력 GOOD
# 화장기초로 GOOD
# 쿨링 OO커버를 한 번에 해결하세요
# OO가 쓰는 기절세럼 건조한 피부에 영양을 듬뿍 넣어주는 세럼 세럼추천
# 이번에 나온 신상 모엘르 베이비오일 식물성 오일이라 끈적이지 않고 풍부한 보습감으로 아이는 물론 임산부 튼살오일로도 GOOD
# OO 스케치북이 있지만 백지라서 그런지 금방 지루해 하는데 딱그림 컬러링롤은 귀여운 캐릭터가 많으니 질리지 않고 오랫동안 가지고 놀기 딱 좋은 아이템
# OO가 좋아하는 동물들이 그려져서 발라주면 더욱 좋아하지요
# 피부가 민감한 OO는 도톰하고 수분감많은 루이비앙물티슈 사용하고 대만족중이예요
# OO AFTER 보고나니 사용하지않을 수 없음
# 우리 OO를 위해 안심하고 사용할수 베베루아 아기세제 아기섬유유연제 선택했어요
# OO이 사용하는 콜라겐마스크팩 토기가 사용해본 어바웃미 더바브랜드의 메디앤서 콜라겐 퍼밍업 마스크
# 겟잇뷰티 MC OO가 추천하는 아윤채 컴플리트 리뉴 키트로 모태머릿결미녀가 되어봅시당
# 사진속에서도 돋보이는 OO 언니의 건강하고 탄력있는 머릿결의 비결인 아윤채 컴플리트 리뉴 키트
# 향도 덜나고 발림성도 GOOD
# 아 만나보니 완전 GOOD
# OO 씨도 사용한다고 하는데 아 정말 이유를 써보니 딱 알겠어
# 완전 커버력 짱에 촉촉함까지 GOOD
# 그라운드에서 뜨거운 자외선을 받는 OO선크림 으로 요즘 핫핫 유명하다면서요
# 거기서 OO 가 슬리브 착용해서 완전 중국 에서 대박난 제품이라고
# 이거 요즘 밥블레스유 에 나오는 OO온니가 쓴다길래 검색해봤더니 홈쇼핑완판템 이라더라구요
# 예민보스 OO가 쓸수있는 제품
# OO가 좋아하니 저두 기쁘네용
# 특히 노랑노랑한 바나나 비누는 OO가 좋아하는 바나나향이 듬뿍나서 손씻을 때 더 좋아하는 것 같아요
# 사랑스러운 일룸가구 덕에 OO방 인테리어도 엄청 이뻐질것 같아서 벌써 설레네요
# 너무 귀여워서 OO가 엄청 좋아하는 피그피기 말랑말랑 아기돼지인형
# OO가 좋아하는거보니 제가 다 므흣
# 건조한 요즘에 보습이 많아서 사용하기도 GOOD
# OO선스틱 제품에 대해 알아볼수록 이건 필수템이구나 싶더라구요
# 다낭 갈 때도 OO선스틱 아이오페 UV쉴드 선스틱 파운데이션은 무조건 꼭 챙겨서 떠날예정이랍니다
# 요즘 핫한 OO 미스트
# 특히 각질제거효과도 있다고해서 왕왕 건조 각질부자 OO에게 핫 아이템
# OO는 살짝 보이는 수분광이 더 좋다는 말
# 촉촉한 파운데이션 락컬러 락 잇 굿 바운데이션 OO PICK
# 요거슨 앞으로 OO PICK 이랍니다
# OO의 유수분은 트리앤씨 에스키모멜라 퍼타일수딩토너로 확 잡아버렸네요
# 색상두 분홍빛에 영롱하고 디자인은 OO마음에 쏙든다는
# 하지만 OO는 좀 피부가 많이 일어나고 바르는데 피부에 딱 붙지 않아서 아쉬웠답니다
# 비비크림에 비해서 톤이 밝아 좋지만 요즘 OO피부가 넘많이 건조해서 어떤 제품을 써도 자꾸만 뜨네요
# 아마 건조한 피부분들은 OO처럼 안맞지 않을까 싶네요
# OO같이 어두운 비비크림쓰면 칙칙해 보이는 피부면 더더욱 좋을듯 싶네요
# 한 달 넘게 OO 팡팡이 머리 얼굴 몸 여기저기 사용해봤는데 트러블이나 빨개진다거나 하는 것 없이 잘 사용하고 있어요
# 처음 알게 된 브랜드라 어떨지 몰라서 OO 상처 진정용으로 큐어순 베이비밤만 써봤는데 아주 만족스러워서 크림과 바스 제품도 구입해볼려구요
# VIRTOO BY LG 라는 어플을 받고 컴퓨터와 연동 시키면 폰에 오는 알림과 전화 메시지를 컴퓨터로 확인 할 수 있다
# 가성비 GOOD
# OO 울서방님도 저도 관련 제품에 대해서는 관심을 가지고 있던 터라 샴푸며 기본적인케어 제품도 사용하고 있지만 좀 더 효율적이며 근본적인 관리를 할 수 있는 제품이있길래 0일째 열심히 사용하고 있어요
# 평소에 일반칫솔을 쓸 땐 대충대충 0분을못 채우고 나왔는데 OO 전동칫솔로 바꾸고 나니 어찌나 꼼꼼하게 닦던지
# OO씨도 추천하는 능력자 무선 청소기
# OO방에 꼭 넣어주고 싶은 공기청정기네요
# 넘나 귀여운 MOOYEE
# 후면 카메라는 0000만 화소와 전면은 000만 화소라 평소 사진촬영을 좋아하는 OO 군에게 아주 안성맞춤이었지 않나 싶을 정도로 마음에 쏙 들었는데 디자인도 그레이 컬러의 곡선형 메탈바디라 세련되기까지
# 다얼유 EH000로 게임 생활이 윤택하게 빛나는 것 같은 OO 군입니다

# %% [markdown]
# ## Reformat

# %%
### new
entity_property_pair = [
    '본품#가격', '본품#다양성', '본품#디자인', '본품#인지도', '본품#일반', '본품#편의성', '본품#품질',
    '브랜드#가격', '브랜드#디자인', '브랜드#인지도', '브랜드#일반', '브랜드#품질',
    '제품 전체#가격', '제품 전체#다양성', '제품 전체#디자인', '제품 전체#인지도', '제품 전체#일반', '제품 전체#편의성', '제품 전체#품질',
    '패키지/구성품#가격', '패키지/구성품#다양성', '패키지/구성품#디자인', '패키지/구성품#일반', '패키지/구성품#편의성', '패키지/구성품#품질'
]

more_tokens = ['&name&', '&affiliation&', '&social-security-num&', '&tel-num&', '&card-num&', '&bank-account&', '&num&', '&online-account&']

new_tokens = entity_property_pair + more_tokens

tf_id_to_name = ['True', 'False']
tf_name_to_id = {tf_id_to_name[i]: i for i in range(len(tf_id_to_name))}

polarity_id_to_name = ['positive', 'negative', 'neutral']
polarity_name_to_id = {polarity_id_to_name[i]: i for i in range(len(polarity_id_to_name))}

# %%
len(entity_property_pair)
# Out:
# 25

# %%
def reformat(df):
    ep =[]
    p = []
    for index, row in df.iterrows():
        utterance = row.sentence_form
        id = row.id

        for pair in entity_property_pair:
            isPairInOpinion = False
            if pd.isna(utterance):
                break
            for annotation in row.annotation:
                entity_property = annotation[0]
                sentiment = annotation[2]
                if entity_property not in entity_property_pair:
                    print(row.id, entity_property)
                if sentiment not in polarity_id_to_name:
                    print(row.id, entity_property, sentiment)
                    continue
                if entity_property == pair:
                    ep.append([id, utterance, entity_property, tf_name_to_id['True']])
                    p.append([id, utterance, entity_property, sentiment])
                    isPairInOpinion = True
                    break

            if isPairInOpinion is False:
                ep.append([id, utterance, pair, tf_name_to_id['False']])

    return ep, p

# %%
def reformat_p_binary(df):
    p_binary = []
    for i, row in df.iterrows():
        row.id, row.sentence_form, row.entity_property, row.sentiment
        for sentiment in polarity_id_to_name:
            if sentiment == row.sentiment:
                p_binary.append([row.id, row.sentence_form, '#'.join([row.entity_property, row.sentiment]), tf_name_to_id['True']])
            else: 
                p_binary.append([row.id, row.sentence_form, '#'.join([row.entity_property, sentiment]), tf_name_to_id['False']])
    return p_binary

# %%
ep_train, p_train = reformat(train)
ep_train = pd.DataFrame(ep_train, columns=['id', 'sentence_form', 'entity_property', 'labels'])
p_train = pd.DataFrame(p_train, columns=['id', 'sentence_form', 'entity_property', 'sentiment'])

ep_dev, p_dev = reformat(dev)
ep_dev = pd.DataFrame(ep_dev, columns=['id', 'sentence_form', 'entity_property', 'labels'])
p_dev = pd.DataFrame(p_dev, columns=['id', 'sentence_form', 'entity_property', 'sentiment'])

# %%
### more than 1 entitiy in a single row
# condition = train.annotation.apply(lambda x: len(x)) > 1
# print(train.annotation[condition].count())
# print(train.annotation[condition].apply(lambda x: len(x)).sum())
# 489-235

# %%
p_binary_train = reformat_p_binary(p_train)
p_binary_train = pd.DataFrame(p_binary_train, columns=['id', 'sentence_form', 'entity_property', 'labels'])

# %%
p_binary_train
# Out:
#                                id  \
# 0     nikluge-sa-2022-train-00001
# 1     nikluge-sa-2022-train-00001
# 2     nikluge-sa-2022-train-00001
# 3     nikluge-sa-2022-train-00002
# 4     nikluge-sa-2022-train-00002
# ...                           ...
# 9583  nikluge-sa-2022-train-03000
# 9584  nikluge-sa-2022-train-03000
# 9585  nikluge-sa-2022-train-03001
# 9586  nikluge-sa-2022-train-03001
# 9587  nikluge-sa-2022-train-03001
#
#                                           sentence_form     entity_property  \
# 0                 둘쨋날은 미친듯이 밟아봤더니 기어가 헛돌면서 틱틱 소리가 나서 경악      본품#품질#positive
# 1                 둘쨋날은 미친듯이 밟아봤더니 기어가 헛돌면서 틱틱 소리가 나서 경악      본품#품질#negative
# 2                 둘쨋날은 미친듯이 밟아봤더니 기어가 헛돌면서 틱틱 소리가 나서 경악       본품#품질#neutral
# 3     이거 뭐 삐꾸를 준 거 아냐 불안하고 거금 투자한 게 왜 이래 싶어서 정이 확 떨어...      본품#품질#positive
# 4     이거 뭐 삐꾸를 준 거 아냐 불안하고 거금 투자한 게 왜 이래 싶어서 정이 확 떨어...      본품#품질#negative
# ...                                                 ...                 ...
# 9583                                  마지막으로 귀여워서 집어온 모자  제품 전체#디자인#negative
# 9584                                  마지막으로 귀여워서 집어온 모자   제품 전체#디자인#neutral
# 9585                                         일본유니클로 사랑해     브랜드#일반#positive
# 9586                                         일본유니클로 사랑해     브랜드#일반#negative
# 9587                                         일본유니클로 사랑해      브랜드#일반#neutral
#
#       labels
# 0          1
# 1          0
# 2          1
# 3          1
# 4          0
# ...      ...
# 9583       1
# 9584       1
# 9585       0
# 9586       1
# 9587       1
#
# [9588 rows x 4 columns]

# %%
p_binary_dev = reformat_p_binary(p_dev)
p_binary_dev = pd.DataFrame(p_binary_dev, columns=['id', 'sentence_form', 'entity_property', 'labels'])

# %%
p_binary_dev
# Out:
#                              id  \
# 0     nikluge-sa-2022-dev-00001
# 1     nikluge-sa-2022-dev-00001
# 2     nikluge-sa-2022-dev-00001
# 3     nikluge-sa-2022-dev-00002
# 4     nikluge-sa-2022-dev-00002
# ...                         ...
# 9001  nikluge-sa-2022-dev-02793
# 9002  nikluge-sa-2022-dev-02793
# 9003  nikluge-sa-2022-dev-02794
# 9004  nikluge-sa-2022-dev-02794
# 9005  nikluge-sa-2022-dev-02794
#
#                                           sentence_form    entity_property  \
# 0     깔끔하게 부직포 포장으로 되어 있어서 그냥 뜨거운 물에 풍덩 넣어놓고 좀 휘젓어주면...    본품#편의성#positive
# 1     깔끔하게 부직포 포장으로 되어 있어서 그냥 뜨거운 물에 풍덩 넣어놓고 좀 휘젓어주면...    본품#편의성#negative
# 2     깔끔하게 부직포 포장으로 되어 있어서 그냥 뜨거운 물에 풍덩 넣어놓고 좀 휘젓어주면...     본품#편의성#neutral
# 3     목욕할 때마다 넣어봤는데 샤워는 자주 해도 목욕은 그렇게 자주가 아님 이것도 약재는...     본품#일반#positive
# 4     목욕할 때마다 넣어봤는데 샤워는 자주 해도 목욕은 그렇게 자주가 아님 이것도 약재는...     본품#일반#negative
# ...                                                 ...                ...
# 9001                                      대형으로 샀더니 잘 맞음  제품 전체#일반#negative
# 9002                                      대형으로 샀더니 잘 맞음   제품 전체#일반#neutral
# 9003                    안경 쓰고 숨 푸악푸악 내쉬어 봤는데 김서림도 거의 없음  제품 전체#품질#positive
# 9004                    안경 쓰고 숨 푸악푸악 내쉬어 봤는데 김서림도 거의 없음  제품 전체#품질#negative
# 9005                    안경 쓰고 숨 푸악푸악 내쉬어 봤는데 김서림도 거의 없음   제품 전체#품질#neutral
#
#       labels
# 0          0
# 1          1
# 2          1
# 3          0
# 4          1
# ...      ...
# 9001       1
# 9002       1
# 9003       0
# 9004       1
# 9005       1
#
# [9006 rows x 4 columns]

# %% [markdown]
# ## Counting

# %%
print('binary_multi: ', end=''), print(len(ep_train), len(ep_dev), len(p_train), len(p_dev))
print('binary_binary: ', end=''), print(len(ep_train), len(ep_dev), len(p_binary_train), len(p_binary_dev))
ep_train = ep_train.drop_duplicates()
ep_dev = ep_dev.drop_duplicates()
p_train = p_train.drop_duplicates()
p_dev = p_dev.drop_duplicates()
p_binary_train = p_binary_train.drop_duplicates()
p_binary_dev = p_binary_dev.drop_duplicates()
print('\nafter drop_duplicates')
print('binary_multi: ', end=''), print(len(ep_train), len(ep_dev), len(p_train), len(p_dev))
print('binary_binary: ', end=''), print(len(ep_train), len(ep_dev), len(p_binary_train), len(p_binary_dev))
# Out:
# binary_multi: 75000 69825 3196 3002
# binary_binary: 75000 69825 9588 9006
#
# after drop_duplicates
# binary_multi: 75000 69825 3196 3002
# binary_binary: 75000 69825 9588 9006
# (None, None)

# %% [markdown]
# ## Save Files

# %%
save_path = './dataset/cleaned_v1'

train.to_csv(f'{save_path}/raw_train.csv', index=False)
dev.to_csv(f'{save_path}/raw_dev.csv', index=False)
test.to_csv(f'{save_path}/raw_test.csv', index=False)

ep_train.to_csv(f'{save_path}/ce_train.csv', index=False)
ep_dev.to_csv(f'{save_path}/ce_dev.csv', index=False)
p_train.to_csv(f'{save_path}/pc_train.csv', index=False)
p_dev.to_csv(f'{save_path}/pc_dev.csv', index=False)
p_binary_train.to_csv(f'{save_path}/pc_binary_train.csv', index=False)
p_binary_dev.to_csv(f'{save_path}/pc_binary_dev.csv', index=False)

# %% [markdown]
# # ASC Augmentation

# %%
model_checkpoint = '/content/drive/MyDrive/aspect_based_sentiment_analysis/base_model/klue_roberta_base/v2/klue_roberta_base_mlm/checkpoint-19860'

tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)
model = AutoModelForMaskedLM.from_pretrained(model_checkpoint)

# %%
sTokens = tokenizer.all_special_tokens

def delTokens(sent):
    sent = sent.split(' ')
    temp = []
    for e in sent:
        if e not in sTokens:
            temp.append(e)
    return ' '.join(temp)

# %%
positive, negative, neutral = p_train[p_train.sentiment == 'positive'], p_train[p_train.sentiment == 'negative'], p_train[p_train.sentiment == 'neutral']

# %%
len(positive), len(negative), len(neutral)
# Out:
# (3043, 58, 95)

# %%
(58 * 3) * 4 * 3, (95 * 3) * 4 * 2 # bt ri rr
# Out:
# (2088, 2280)

# %% [markdown]
# Back Translation / Random Insertion / Random Replacement / Random Swap / Random Deletion

# %%
def backTrans(text):
    aug1 = ts.papago(text, sleep_seconds=5, from_language='ko', to_language='en')
    aug1 = ts.papago(aug1, sleep_seconds=5, from_language='en', to_language='ko')

    aug2 = ts.papago(text, sleep_seconds=5, from_language='ko', to_language='ja')
    aug2 = ts.papago(aug2, sleep_seconds=5, from_language='ja', to_language='ko')

    return [aug1, aug2]

def randomInsert(num, sample, device):
    aug = naw.ContextualWordEmbsAug(
        model_path=model_checkpoint, action="insert", model_type='bert', top_k=5, aug_p=0.3, aug_min=1, aug_max=1, device=device)

    aug_result = aug.augment(sample, n=num, num_thread=12)
    aug_result = list(map(delTokens, aug_result))
    aug_result = list(set(aug_result))
    return aug_result

def randomReplace(num, sample, device):
    aug = naw.ContextualWordEmbsAug(
        model_path=model_checkpoint, action="insert", model_type='bert', top_k=5, aug_p=0.3, aug_min=1, aug_max=1, device=device)

    aug_result = aug.augment(sample, n=num, num_thread=12)
    aug_result = list(map(delTokens, aug_result))
    aug_result = list(set(aug_result))
    return aug_result

def randomSwap(num, sample):
    aug = naw.RandomWordAug(action='swap', aug_min=1, aug_max=1, aug_p=0.3)    
    aug_result = aug.augment(sample, n=num, num_thread=2)
    aug_result = list(set(aug_result))
    return aug_result

def randomSplit(num, sample):
    aug = naw.SplitAug(aug_min=1, aug_max=1, aug_p=0.3, min_char=3)
    aug_result = aug.augment(sample, n=num, num_thread=2)
    aug_result = list(set(aug_result))
    return aug_result

# %%
(58 * 3) * 5 * 4, (95 * 3) * 4 * 3 # bt ri rr
# Out:
# (3480, 3420)

# %%
def backtransRoutine(data2augment, output_path):
    print('back translation started.')
    temp = []
    for row in data2augment:
        augs = backTrans(row[1])
        for aug in augs:
            if aug != '' and aug != row[1]:
                new = [row[0], aug, row[2], row[3]]
                if new not in data2augment:
                    temp.append(new)
    data2augment.extend(temp)
    print(len(f'back translation finished.\ncurrent count: {len(data2augment)}'))

    data_aug = pd.DataFrame(data2augment, columns=['id', 'sentence_form', 'entity_property', 'sentiment'])
    data_aug.to_csv(f'{output_path}', index=False)

    return data_aug

# %%
import os

def edaRoutine(data2augment, ri, rr, output_path):
    print(f'current count: {len(data2augment)}')
    print('random insertion started.')
    temp = []
    for row in data2augment:
        augs = randomInsert(ri, row[1], 'cuda')
        for aug in augs:
            if aug != '' and aug != row[1]:
                new = [row[0], aug, row[2], row[3]]
                if new not in data2augment:
                    temp.append(new)
    data2augment.extend(temp)
    print(f'random insertion finished.\ncurrent count: {len(data2augment)}')

    print('random replacement started.')
    temp = []
    for row in data2augment:
        augs = randomReplace(rr, row[1], 'cuda')
        for aug in augs:
            if aug != '' and aug != row[1]:
                new = [row[0], aug, row[2], row[3]]
                if new not in data2augment:
                    temp.append(new)
    data2augment.extend(temp)
    print(f'random replacement finished.\ncurrent count: {len(data2augment)}')

    print('random swap and split started.')
    while len(data2augment) < len(positive):
        temp = []
        k = random.randrange(len(negative))
        id, text, entity, sentiment = data2augment[k]

        selector = random.randint(0,1)
        if selector == 0:
            augs = randomSwap(1, text)
            for aug in augs:
                if aug != '' and aug != text:
                    new = [id, aug, entity, sentiment]
                    if new not in data2augment:
                        temp.append(new)
            data2augment.extend(temp)
        else:
            augs = randomSplit(1, text)
            for aug in augs:
                if aug != '' and aug != text:
                    new = [id, aug, entity, sentiment]
                    if new not in data2augment:
                        temp.append(new)
            data2augment.extend(temp)
        if len(data2augment)%25 == 0:
            print(f'random swap and split in progress.\ncurrent count: {len(data2augment)}')

    print(f'whole augmentation routine finished.\ntotal count: {len(data2augment)}')

    data_aug = pd.DataFrame(data2augment, columns=['id', 'sentence_form', 'entity_property', 'sentiment'])
    data_aug.to_csv(f'{output_path}', index=False)

    return data_aug

# %%
### negative
# # back translation

# data2augment = negative.values.tolist()

output_folder = '/content/drive/MyDrive/aspect_based_sentiment_analysis/data/v11'
output_file = 'negative_bt.csv'
output_path = os.path.join(output_folder, output_file)

# negative_bt = backtransRoutine(data2augment, output_path)
negative_bt = pd.read_csv(output_path)
negative_bt = negative_bt.values.tolist()
# RI / RR

ri = 4 # times - 1
rr = 3 # times - 1

output_folder = '/content/drive/MyDrive/aspect_based_sentiment_analysis/data/v11'
output_file = 'negative_aug.csv'
output_path = os.path.join(output_folder, output_file)

# negative_aug = edaRoutine(negative_bt, ri, rr, output_path)
negative_aug = pd.read_csv(output_path)

# %%
negative_aug
negative_aug = negative_aug.drop_duplicates()

# %%
# negative_aug.sample(n=15, frac=None, replace=False, weights=None, random_state=None, axis=None, ignore_index=False)

# %%
# negative_aug.sort_values('id').head(50).sentence_form

# %%
### neutral
# back translation

# data2augment = neutral.values.tolist()

output_folder = '/content/drive/MyDrive/aspect_based_sentiment_analysis/data/v11'
output_file = 'neutral_bt.csv'
output_path = os.path.join(output_folder, output_file)

# neutral_bt = backtransRoutine(data2augment, output_path)
neutral_bt = pd.read_csv(output_path)
neutral_bt = neutral_bt.values.tolist()

# RI / RR

ri = 3 # times - 1
rr = 2 # times - 1

output_folder = '/content/drive/MyDrive/aspect_based_sentiment_analysis/data/v11'
output_file = 'neutral_aug.csv'
output_path = os.path.join(output_folder, output_file)

# neutral_aug = edaRoutine(neutral_bt, ri, rr, output_path)
neutral_aug = pd.read_csv(output_path)

# %%
neutral_aug
neutral_aug = neutral_aug.drop_duplicates()

# %%
# neutral_aug.sample(n=15, frac=None, replace=False, weights=None, random_state=None, axis=None, ignore_index=False)

# %%
# neutral_aug.sort_values('id').head(50).sentence_form

# %%
p_train_aug = pd.concat([positive, negative_aug, neutral_aug])

# %%
def reformat_p_binary(df):
    p_binary = []
    for i, row in df.iterrows():
        row.id, row.sentence_form, row.entity_property, row.sentiment
        for sentiment in polarity_id_to_name:
            if sentiment == row.sentiment:
                p_binary.append([row.id, row.sentence_form, '#'.join([row.entity_property, row.sentiment]), tf_name_to_id['True']])
            else: 
                p_binary.append([row.id, row.sentence_form, '#'.join([row.entity_property, sentiment]), tf_name_to_id['False']])
    return p_binary

# %%
p_binary_train_aug = reformat_p_binary(p_train_aug)
p_binary_train_aug = pd.DataFrame(p_binary_train_aug, columns=['id', 'sentence_form', 'entity_property', 'labels'])

# %%
p_binary_train_aug
# Out:
#                                 id                             sentence_form  \
# 0      nikluge-sa-2022-train-00003      간사하게도 그 이후에는 라이딩이 아주 즐거워져서 만족스럽게 탔다.
# 1      nikluge-sa-2022-train-00003      간사하게도 그 이후에는 라이딩이 아주 즐거워져서 만족스럽게 탔다.
# 2      nikluge-sa-2022-train-00003      간사하게도 그 이후에는 라이딩이 아주 즐거워져서 만족스럽게 탔다.
# 3      nikluge-sa-2022-train-00006  지금 내 실력과 저질 체력으로는 이 정도 자전거도 되게 훌륭한 거라는..
# 4      nikluge-sa-2022-train-00006  지금 내 실력과 저질 체력으로는 이 정도 자전거도 되게 훌륭한 거라는..
# ...                            ...                                       ...
# 27316  nikluge-sa-2022-train-00048               600원짜리 컵인데 더 이상을 바랄 없을 순 듯.
# 27317  nikluge-sa-2022-train-00048               600원짜리 컵인데 더 이상을 바랄 없을 순 듯.
# 27318  nikluge-sa-2022-train-01352  사진 찍는데 액정으론 내가 괜히샀나 싶 었는데 보정하려고 보니 대만족..
# 27319  nikluge-sa-2022-train-01352  사진 찍는데 액정으론 내가 괜히샀나 싶 었는데 보정하려고 보니 대만족..
# 27320  nikluge-sa-2022-train-01352  사진 찍는데 액정으론 내가 괜히샀나 싶 었는데 보정하려고 보니 대만족..
#
#          entity_property  labels
# 0      제품 전체#일반#positive       0
# 1      제품 전체#일반#negative       1
# 2       제품 전체#일반#neutral       1
# 3      제품 전체#일반#positive       0
# 4      제품 전체#일반#negative       1
# ...                  ...     ...
# 27316  제품 전체#일반#negative       1
# 27317   제품 전체#일반#neutral       0
# 27318     본품#품질#positive       1
# 27319     본품#품질#negative       1
# 27320      본품#품질#neutral       0
#
# [27321 rows x 4 columns]

# %%
p_binary_dev = reformat_p_binary(p_dev)
p_binary_dev = pd.DataFrame(p_binary_dev, columns=['id', 'sentence_form', 'entity_property', 'labels'])

# %%
p_binary_dev
# Out:
#                              id  \
# 0     nikluge-sa-2022-dev-00001
# 1     nikluge-sa-2022-dev-00001
# 2     nikluge-sa-2022-dev-00001
# 3     nikluge-sa-2022-dev-00002
# 4     nikluge-sa-2022-dev-00002
# ...                         ...
# 9001  nikluge-sa-2022-dev-02793
# 9002  nikluge-sa-2022-dev-02793
# 9003  nikluge-sa-2022-dev-02794
# 9004  nikluge-sa-2022-dev-02794
# 9005  nikluge-sa-2022-dev-02794
#
#                                           sentence_form    entity_property  \
# 0     깔끔하게 부직포 포장으로 되어 있어서 그냥 뜨거운 물에 풍덩 넣어놓고 좀 휘젓어주면...    본품#편의성#positive
# 1     깔끔하게 부직포 포장으로 되어 있어서 그냥 뜨거운 물에 풍덩 넣어놓고 좀 휘젓어주면...    본품#편의성#negative
# 2     깔끔하게 부직포 포장으로 되어 있어서 그냥 뜨거운 물에 풍덩 넣어놓고 좀 휘젓어주면...     본품#편의성#neutral
# 3     목욕할 때마다 넣어봤는데(샤워는 자주 해도 목욕은 그렇게 자주가 아님.. 이것도 약...     본품#일반#positive
# 4     목욕할 때마다 넣어봤는데(샤워는 자주 해도 목욕은 그렇게 자주가 아님.. 이것도 약...     본품#일반#negative
# ...                                                 ...                ...
# 9001                                     대형으로 샀더니 잘 맞음.  제품 전체#일반#negative
# 9002                                     대형으로 샀더니 잘 맞음.   제품 전체#일반#neutral
# 9003                   안경 쓰고 숨 푸악푸악 내쉬어 봤는데 김서림도 거의 없음.  제품 전체#품질#positive
# 9004                   안경 쓰고 숨 푸악푸악 내쉬어 봤는데 김서림도 거의 없음.  제품 전체#품질#negative
# 9005                   안경 쓰고 숨 푸악푸악 내쉬어 봤는데 김서림도 거의 없음.   제품 전체#품질#neutral
#
#       labels
# 0          0
# 1          1
# 2          1
# 3          0
# 4          1
# ...      ...
# 9001       1
# 9002       1
# 9003       0
# 9004       1
# 9005       1
#
# [9006 rows x 4 columns]

# %% [markdown]
# # Counting

# %%
len(ep_train), len(ep_dev), len(p_train), len(p_dev)
# Out:
# (75000, 69825, 3196, 3002)

# %%
len(ep_train), len(ep_dev), len(p_binary_train_aug), len(p_binary_dev)
# Out:
# (75000, 69825, 27321, 9006)

# %%
ep_train = ep_train.drop_duplicates()
p_binary_train_aug = p_binary_train_aug.drop_duplicates()
ep_dev = ep_dev.drop_duplicates()
p_binary_dev = p_binary_dev.drop_duplicates()
len(ep_train), len(ep_dev), len(p_binary_train_aug), len(p_binary_dev)
# Out:
# (75000, 69825, 27321, 9006)

# %% [markdown]
# # Export

# %%
# %cd /content/drive/MyDrive/aspect_based_sentiment_analysis/data/v11

# train.to_csv('raw_train.csv', index=False)
# dev.to_csv('raw_dev.csv', index=False)
# test.to_csv('raw_test.csv', index=False)

ep_train.to_csv('ce_train.csv', index=False)
p_binary_train_aug.to_csv('pc_binary_train_aug.csv', index=False)
ep_dev.to_csv('ce_dev.csv', index=False)
p_binary_dev.to_csv('pc_binary_dev.csv', index=False)
# Out:
# /content/drive/MyDrive/aspect_based_sentiment_analysis/data/v11

# %%
# emojis = pd.concat([ep_train.sentence_form, p_train.sentence_form, ep_dev.sentence_form, p_dev.sentence_form], ignore_index=True, verify_integrity=True).to_frame()
# emojis = list(set(demoji.findall(' '.join(emojis.sentence_form.to_list())).keys()))

# %%
df = pd.read_csv('ce_train.csv')
df[df.id == 'nikluge-sa-2022-train-00065']
# Out:
#                                id  \
# 1600  nikluge-sa-2022-train-00065
# 1601  nikluge-sa-2022-train-00065
# 1602  nikluge-sa-2022-train-00065
# 1603  nikluge-sa-2022-train-00065
# 1604  nikluge-sa-2022-train-00065
# 1605  nikluge-sa-2022-train-00065
# 1606  nikluge-sa-2022-train-00065
# 1607  nikluge-sa-2022-train-00065
# 1608  nikluge-sa-2022-train-00065
# 1609  nikluge-sa-2022-train-00065
# 1610  nikluge-sa-2022-train-00065
# 1611  nikluge-sa-2022-train-00065
# 1612  nikluge-sa-2022-train-00065
# 1613  nikluge-sa-2022-train-00065
# 1614  nikluge-sa-2022-train-00065
# 1615  nikluge-sa-2022-train-00065
# 1616  nikluge-sa-2022-train-00065
# 1617  nikluge-sa-2022-train-00065
# 1618  nikluge-sa-2022-train-00065
# 1619  nikluge-sa-2022-train-00065
# 1620  nikluge-sa-2022-train-00065
# 1621  nikluge-sa-2022-train-00065
# 1622  nikluge-sa-2022-train-00065
# 1623  nikluge-sa-2022-train-00065
# 1624  nikluge-sa-2022-train-00065
#
#                                     sentence_form entity_property  labels
# 1600  봉제선이 앞코 쪽에 딱 한군데 있고 맥스나 테니스 클래식 등보다 훨씬 편하다.           본품#가격       1
# 1601  봉제선이 앞코 쪽에 딱 한군데 있고 맥스나 테니스 클래식 등보다 훨씬 편하다.          본품#다양성       1
# 1602  봉제선이 앞코 쪽에 딱 한군데 있고 맥스나 테니스 클래식 등보다 훨씬 편하다.          본품#디자인       1
# 1603  봉제선이 앞코 쪽에 딱 한군데 있고 맥스나 테니스 클래식 등보다 훨씬 편하다.          본품#인지도       1
# 1604  봉제선이 앞코 쪽에 딱 한군데 있고 맥스나 테니스 클래식 등보다 훨씬 편하다.           본품#일반       1
# 1605  봉제선이 앞코 쪽에 딱 한군데 있고 맥스나 테니스 클래식 등보다 훨씬 편하다.          본품#편의성       1
# 1606  봉제선이 앞코 쪽에 딱 한군데 있고 맥스나 테니스 클래식 등보다 훨씬 편하다.           본품#품질       1
# 1607  봉제선이 앞코 쪽에 딱 한군데 있고 맥스나 테니스 클래식 등보다 훨씬 편하다.          브랜드#가격       1
# 1608  봉제선이 앞코 쪽에 딱 한군데 있고 맥스나 테니스 클래식 등보다 훨씬 편하다.         브랜드#디자인       1
# 1609  봉제선이 앞코 쪽에 딱 한군데 있고 맥스나 테니스 클래식 등보다 훨씬 편하다.         브랜드#인지도       1
# 1610  봉제선이 앞코 쪽에 딱 한군데 있고 맥스나 테니스 클래식 등보다 훨씬 편하다.          브랜드#일반       1
# 1611  봉제선이 앞코 쪽에 딱 한군데 있고 맥스나 테니스 클래식 등보다 훨씬 편하다.          브랜드#품질       1
# 1612  봉제선이 앞코 쪽에 딱 한군데 있고 맥스나 테니스 클래식 등보다 훨씬 편하다.        제품 전체#가격       1
# 1613  봉제선이 앞코 쪽에 딱 한군데 있고 맥스나 테니스 클래식 등보다 훨씬 편하다.       제품 전체#다양성       1
# 1614  봉제선이 앞코 쪽에 딱 한군데 있고 맥스나 테니스 클래식 등보다 훨씬 편하다.       제품 전체#디자인       0
# 1615  봉제선이 앞코 쪽에 딱 한군데 있고 맥스나 테니스 클래식 등보다 훨씬 편하다.       제품 전체#인지도       1
# 1616  봉제선이 앞코 쪽에 딱 한군데 있고 맥스나 테니스 클래식 등보다 훨씬 편하다.        제품 전체#일반       1
# 1617  봉제선이 앞코 쪽에 딱 한군데 있고 맥스나 테니스 클래식 등보다 훨씬 편하다.       제품 전체#편의성       0
# 1618  봉제선이 앞코 쪽에 딱 한군데 있고 맥스나 테니스 클래식 등보다 훨씬 편하다.        제품 전체#품질       1
# 1619  봉제선이 앞코 쪽에 딱 한군데 있고 맥스나 테니스 클래식 등보다 훨씬 편하다.      패키지/구성품#가격       1
# 1620  봉제선이 앞코 쪽에 딱 한군데 있고 맥스나 테니스 클래식 등보다 훨씬 편하다.     패키지/구성품#다양성       1
# 1621  봉제선이 앞코 쪽에 딱 한군데 있고 맥스나 테니스 클래식 등보다 훨씬 편하다.     패키지/구성품#디자인       1
# 1622  봉제선이 앞코 쪽에 딱 한군데 있고 맥스나 테니스 클래식 등보다 훨씬 편하다.      패키지/구성품#일반       1
# 1623  봉제선이 앞코 쪽에 딱 한군데 있고 맥스나 테니스 클래식 등보다 훨씬 편하다.     패키지/구성품#편의성       1
# 1624  봉제선이 앞코 쪽에 딱 한군데 있고 맥스나 테니스 클래식 등보다 훨씬 편하다.      패키지/구성품#품질       1

# %%
df = pd.read_csv('ce_dev.csv')
df
# Out:
#                               id  \
# 0      nikluge-sa-2022-dev-00001
# 1      nikluge-sa-2022-dev-00001
# 2      nikluge-sa-2022-dev-00001
# 3      nikluge-sa-2022-dev-00001
# 4      nikluge-sa-2022-dev-00001
# ...                          ...
# 69820  nikluge-sa-2022-dev-02794
# 69821  nikluge-sa-2022-dev-02794
# 69822  nikluge-sa-2022-dev-02794
# 69823  nikluge-sa-2022-dev-02794
# 69824  nikluge-sa-2022-dev-02794
#
#                                            sentence_form entity_property  \
# 0      깔끔하게 부직포 포장으로 되어 있어서 그냥 뜨거운 물에 풍덩 넣어놓고 좀 휘젓어주면...           본품#가격
# 1      깔끔하게 부직포 포장으로 되어 있어서 그냥 뜨거운 물에 풍덩 넣어놓고 좀 휘젓어주면...          본품#다양성
# 2      깔끔하게 부직포 포장으로 되어 있어서 그냥 뜨거운 물에 풍덩 넣어놓고 좀 휘젓어주면...          본품#디자인
# 3      깔끔하게 부직포 포장으로 되어 있어서 그냥 뜨거운 물에 풍덩 넣어놓고 좀 휘젓어주면...          본품#인지도
# 4      깔끔하게 부직포 포장으로 되어 있어서 그냥 뜨거운 물에 풍덩 넣어놓고 좀 휘젓어주면...           본품#일반
# ...                                                  ...             ...
# 69820                   안경 쓰고 숨 푸악푸악 내쉬어 봤는데 김서림도 거의 없음.     패키지/구성품#다양성
# 69821                   안경 쓰고 숨 푸악푸악 내쉬어 봤는데 김서림도 거의 없음.     패키지/구성품#디자인
# 69822                   안경 쓰고 숨 푸악푸악 내쉬어 봤는데 김서림도 거의 없음.      패키지/구성품#일반
# 69823                   안경 쓰고 숨 푸악푸악 내쉬어 봤는데 김서림도 거의 없음.     패키지/구성품#편의성
# 69824                   안경 쓰고 숨 푸악푸악 내쉬어 봤는데 김서림도 거의 없음.      패키지/구성품#품질
#
#        labels
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# ...       ...
# 69820       1
# 69821       1
# 69822       1
# 69823       1
# 69824       1
#
# [69825 rows x 4 columns]

# %%
df = pd.read_csv('pc_binary_train_aug.csv')
df
# Out:
#                                 id                             sentence_form  \
# 0      nikluge-sa-2022-train-00003      간사하게도 그 이후에는 라이딩이 아주 즐거워져서 만족스럽게 탔다.
# 1      nikluge-sa-2022-train-00003      간사하게도 그 이후에는 라이딩이 아주 즐거워져서 만족스럽게 탔다.
# 2      nikluge-sa-2022-train-00003      간사하게도 그 이후에는 라이딩이 아주 즐거워져서 만족스럽게 탔다.
# 3      nikluge-sa-2022-train-00006  지금 내 실력과 저질 체력으로는 이 정도 자전거도 되게 훌륭한 거라는..
# 4      nikluge-sa-2022-train-00006  지금 내 실력과 저질 체력으로는 이 정도 자전거도 되게 훌륭한 거라는..
# ...                            ...                                       ...
# 27316  nikluge-sa-2022-train-00048               600원짜리 컵인데 더 이상을 바랄 없을 순 듯.
# 27317  nikluge-sa-2022-train-00048               600원짜리 컵인데 더 이상을 바랄 없을 순 듯.
# 27318  nikluge-sa-2022-train-01352  사진 찍는데 액정으론 내가 괜히샀나 싶 었는데 보정하려고 보니 대만족..
# 27319  nikluge-sa-2022-train-01352  사진 찍는데 액정으론 내가 괜히샀나 싶 었는데 보정하려고 보니 대만족..
# 27320  nikluge-sa-2022-train-01352  사진 찍는데 액정으론 내가 괜히샀나 싶 었는데 보정하려고 보니 대만족..
#
#          entity_property  labels
# 0      제품 전체#일반#positive       0
# 1      제품 전체#일반#negative       1
# 2       제품 전체#일반#neutral       1
# 3      제품 전체#일반#positive       0
# 4      제품 전체#일반#negative       1
# ...                  ...     ...
# 27316  제품 전체#일반#negative       1
# 27317   제품 전체#일반#neutral       0
# 27318     본품#품질#positive       1
# 27319     본품#품질#negative       1
# 27320      본품#품질#neutral       0
#
# [27321 rows x 4 columns]

# %%
df = pd.read_csv('pc_binary_dev.csv')
df
# Out:
#                              id  \
# 0     nikluge-sa-2022-dev-00001
# 1     nikluge-sa-2022-dev-00001
# 2     nikluge-sa-2022-dev-00001
# 3     nikluge-sa-2022-dev-00002
# 4     nikluge-sa-2022-dev-00002
# ...                         ...
# 9001  nikluge-sa-2022-dev-02793
# 9002  nikluge-sa-2022-dev-02793
# 9003  nikluge-sa-2022-dev-02794
# 9004  nikluge-sa-2022-dev-02794
# 9005  nikluge-sa-2022-dev-02794
#
#                                           sentence_form    entity_property  \
# 0     깔끔하게 부직포 포장으로 되어 있어서 그냥 뜨거운 물에 풍덩 넣어놓고 좀 휘젓어주면...    본품#편의성#positive
# 1     깔끔하게 부직포 포장으로 되어 있어서 그냥 뜨거운 물에 풍덩 넣어놓고 좀 휘젓어주면...    본품#편의성#negative
# 2     깔끔하게 부직포 포장으로 되어 있어서 그냥 뜨거운 물에 풍덩 넣어놓고 좀 휘젓어주면...     본품#편의성#neutral
# 3     목욕할 때마다 넣어봤는데(샤워는 자주 해도 목욕은 그렇게 자주가 아님.. 이것도 약...     본품#일반#positive
# 4     목욕할 때마다 넣어봤는데(샤워는 자주 해도 목욕은 그렇게 자주가 아님.. 이것도 약...     본품#일반#negative
# ...                                                 ...                ...
# 9001                                     대형으로 샀더니 잘 맞음.  제품 전체#일반#negative
# 9002                                     대형으로 샀더니 잘 맞음.   제품 전체#일반#neutral
# 9003                   안경 쓰고 숨 푸악푸악 내쉬어 봤는데 김서림도 거의 없음.  제품 전체#품질#positive
# 9004                   안경 쓰고 숨 푸악푸악 내쉬어 봤는데 김서림도 거의 없음.  제품 전체#품질#negative
# 9005                   안경 쓰고 숨 푸악푸악 내쉬어 봤는데 김서림도 거의 없음.   제품 전체#품질#neutral
#
#       labels
# 0          0
# 1          1
# 2          1
# 3          0
# 4          1
# ...      ...
# 9001       1
# 9002       1
# 9003       0
# 9004       1
# 9005       1
#
# [9006 rows x 4 columns]
